# %%
import nbformat

from nbformat.v4 import new_notebook

# %%
# Out:
# 1547.88s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Chris_Fonnesbeck   OpenVisConf2014	   get-pip.py	      pytest.py
# MIT_Python_6.0001  Scipy_2016_Time_Series  html5up-massively
# MIT_Python_6.0002  Time-Series-Analysis    mojo_files

# %%
??nbformat
# Out:
# Type:        module
# String form: <module 'nbformat' from '/usr/local/lib/python3.10/dist-packages/nbformat/__init__.py'>
# File:        /usr/local/lib/python3.10/dist-packages/nbformat/__init__.py
# Source:
# """The Jupyter notebook format
#
# Use this module to read or write notebook files as particular nbformat versions.
# """
#
# # Copyright (c) IPython Development Team.
# # Distributed under the terms of the Modified BSD License.
#
# from traitlets.log import get_logger
#
# from . import v1, v2, v3, v4
# from ._version import __version__, version_info
# from .sentinel import Sentinel
#
# __all__ = [
#     "versions",
#     "validate",
#     "ValidationError",
#     "convert",
#     "from_dict",
#     "NotebookNode",
#     "current_nbformat",
#     "current_nbformat_minor",
#     "NBFormatError",
#     "NO_CONVERT",
#     "reads",
#     "read",
#     "writes",
#     "write",
#     "version_info",
#     "__version__",
#     "Sentinel",
# ]
#
# versions = {
#     1: v1,
# ...

# %%
# Load the old notebook (replace 'old_notebook.ipynb' with your actual filename)
with open('OpenVisConf2014/Seaborn.ipynb', 'r') as f:
    old_nb = nbformat.read(f, as_version=4)  # Assuming the old format is version 4

# Create a new notebook with the latest format
#new_nb = nbformat.v4.new_notebook()

# Copy cells from the old notebook to the new one
#new_nb.cells.extend(old_nb.cells)

# Save the new notebook (replace 'new_notebook.ipynb' with your desired filename)
# with open('new_notebook.ipynb', 'w') as f:
    # nbformat.write(new_nb, f)
nbformat.write(old_nb, "OpenVisConf2014/Seaborn.ipynb")

# %%
nbformat.validate(old_nb)
